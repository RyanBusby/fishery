# %% [markdown]
# ## Train convolutional neural network with all processed image data

# %%
run conv_net.py
# Out:
# Using TensorFlow backend.
# enter name to save model: conv_net
# Train on 2293 samples, validate on 765 samples
# Epoch 1/50
# 2293/2293 [==============================] - 58s - loss: 1.7966 - acc: 0.3240 - val_loss: 1.8057 - val_acc: 0.3830
# Epoch 2/50
# 2293/2293 [==============================] - 50s - loss: 1.7510 - acc: 0.3668 - val_loss: 1.7578 - val_acc: 0.3817
# Epoch 3/50
# 2293/2293 [==============================] - 50s - loss: 1.7089 - acc: 0.3785 - val_loss: 1.7150 - val_acc: 0.3817
# Epoch 4/50
# 2293/2293 [==============================] - 50s - loss: 1.6590 - acc: 0.3890 - val_loss: 1.6581 - val_acc: 0.3843
# Epoch 5/50
# 2293/2293 [==============================] - 50s - loss: 1.5889 - acc: 0.4108 - val_loss: 1.5811 - val_acc: 0.4275
# Epoch 6/50
# 2293/2293 [==============================] - 50s - loss: 1.4946 - acc: 0.4597 - val_loss: 1.4296 - val_acc: 0.4837
# Epoch 7/50
# ...
