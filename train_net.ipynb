# %% [markdown]
# lr = .00008, filters = 36/72

# %%
run conv_net.py
# Out:
# Using TensorFlow backend.
# enter name to save model: conv_net8
# enter prefix to data file:
# Train on 2293 samples, validate on 765 samples
# Epoch 1/50
# 2293/2293 [==============================] - 84s - loss: 1.7961 - acc: 0.3197 - val_loss: 1.8031 - val_acc: 0.3255
# Epoch 2/50
# 2293/2293 [==============================] - 71s - loss: 1.7595 - acc: 0.3585 - val_loss: 1.7655 - val_acc: 0.3817
# Epoch 3/50
# 2293/2293 [==============================] - 71s - loss: 1.7238 - acc: 0.3764 - val_loss: 1.7262 - val_acc: 0.3817
# Epoch 4/50
# 2293/2293 [==============================] - 71s - loss: 1.6921 - acc: 0.3833 - val_loss: 1.6902 - val_acc: 0.3830
# Epoch 5/50
# 2293/2293 [==============================] - 71s - loss: 1.6557 - acc: 0.3947 - val_loss: 1.6496 - val_acc: 0.3895
# Epoch 6/50
# 2293/2293 [==============================] - 71s - loss: 1.5824 - acc: 0.4174 - val_loss: 1.5316 - val_acc: 0.4340
# Epoch 7/50
# ...
